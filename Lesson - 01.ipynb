# %% [markdown]
# # Hello, and welcom to Python course for beginners.
# ![](https://images.freeimages.com/images/premium/small-comps/8024/8024961-business-handshake.jpg)
#
#
# ## I'm Perry Shoham,
# ## Email  :   Perry.Shoham@gmail.com
# ## Phone #:   052-8118618
#
#
# ### Please add your name, Email and phone number on the next lines below.
#
# ## Name:
# ## Email:
# ## Phone #:
#
# ( To be able editing this test, just double click on the cell/text )
#
#
# ## This page is called Notebook
#
#
# ### This cell is called Markdown cell text
#
# You can add Markdown as much as you want to clearify you code for others and for yourself :)

# %% [markdown]
# Now let's start with Python.
#
# To program code we will use "Code cell"
#
# Code can be executed by choosing it and press and then by pressing ctrl-enter, or by mouse clicking the "PLAY" triangular on the left side of the call.
#
# First, lets define varible, and print it:

# %%
a = 13
print (a)

# %% [markdown]
# Now lets use plus (+) function on vrariables

# %%
a = 7
b = 8
c = a + b

print (c)

# %% [markdown]
# The function 'print' can be used to print strings:

# %%
print ('Hello from Python')
print ("=================")

# %% [markdown]
# We will look at some ways to combine text with data:

# %%
print (a, ' + ', b, ' = ', c )

# %%
print ('{} x {} = {}'.format(a, b, a * b))

# %%
print ('{} : {} = {}'.format(b, a, b / a))

# %%
a = 1
b = 7
c = a/b

print ('type(a) is: ', type(a))
print ('type(b) is: ', type(b))
print ('type(b) is: ', type(c))

# %%
print ('{} : {} = {:.2f}'.format(a, a, a / b))
