# %% [markdown]
# # Hello, and welcom to Python course for beginners.
# ![](https://static.skaip.org/img/emoticons/180x180/f6fcff/handshake.gif)
#
#
# ## I'm Perry Shoham,
# ## Email  :   Perry.Shoham@gmail.com
# ## Phone #:   052-8118618
#
#
# ---

# %% [markdown]
# # How to learn to program (or how to learn in general)
#
# ![](https://www.hello-world.com/images/vocabulary/N974.png)

# %% [markdown]
# # About the course:
#
#
# ### The course will have 10 Zoom sessions of 1.5 hour each, once a week.
# ### The course will take place on Kaggle Notebook platform.
# ### At the beginning of each lesson, everyone will upload the full lesson Notebook, and the lesson will be according to it.
# ### So please use your phone connect the Zoom meeting while you using your computer to follow the lesson and to practice.
#
# ## Syllabus:
# ### 1 - Python environment, Variables, Types, print, basic mathematical functions.
# ### 2 - Arrays, Tuples, Dictionary, Loops, and conditions.
# ### 3 - Functions, arguments, local/global variables.
# ### 4 -	Plots (numpy + matplotlib).
# ### 5 -	Advanced plots bar/pie/scatter.
# ### 6 -	Read and analyze csv files.
# ### 7 -	Datasets – Kaggle, gapminder, Bubble chart
# ### 8 -	Images – openCV
# ### 9 -	Introduction to Neural network
# ### 10-	 Building and training neural network
#
#
#
# ---

# %% [markdown]
# # Today's class:
#
# ### 1. Kaggle environment
# ### 2. Variables & Variable types
# ### 3. Printing
# ### 4. Importing a Python file
# ### 5. Basic mathematical functions
# ### 6. Inputs
# ### 7. Working with dates
# ### 8. Getting USD to NIS currency rate

# %% [markdown]
# ![](https://miro.medium.com/max/837/1*Ab299OETAeuTEiGg5TwpMQ.png)
# # Now it's the time to open *Kaggle* and load this Notebook

# %% [markdown]
# ### Please add your name, Email and phone number on the next lines .
#
# ## Name:
# ## Email:
# ## Phone #:
#
# ### My expectations from this course:
#
# ( In order to edit this test, just double click on the cell/text )
#
#
# ## This page is called "Notebook"
#
#
# ### This cell is called Markdown cell text
#
# You can add Markdowns as much as you want to clearify your code for others and for yourself :)

# %% [markdown]
# ---
# ![](https://icon-library.com/images/python-icon-png/python-icon-png-3.jpg)
#
#
# ## Now let's start with Python.
#
# #### We will work on Python version 3.
# #### Python is an Object-Oriented Programming (OOP) language.
#
# #### "Code cell" is were we will program and execute our code.
#
# #### Code can be executed by single-clicking it and then pressing ctrl-enter, or by mouse clicking the "PLAY" triangle on the left side of the cell.
#
# #### First, lets define varible, and print it:

# %%
# This is a remark line. You can add it to clearify your code, starting with '#'

a = 13
print (a)

# %% [markdown]
# Now lets use plus (+) operator on vrariables

# %%
a = 7
 b = 8
c = a + b

print (c)

# %% [markdown]
# (In this lesson we will represent code without indentation at all, in the following lessons we will talk about indentation)
# https://he.wikipedia.org/wiki/%D7%94%D7%96%D7%97%D7%94
#
# The function 'print' can be used to print strings as well:

# %%
print ('Hello from Python')
print ("=================")

# %% [markdown]
# How can we combine texts with numbers?

# %%
print (a, '+', b, '=', c )

# %% [markdown]
# We can change the 'end' and the 'sep' or both if needed

# %%
print (a, '+', b, '=', c ,end='')

print (a, '+', b, '=', c, sep='')

# %% [markdown]
# We can define multiple text lines using tripple "

# %%
a = """  This is Major Tom to Ground Control
     I'm stepping through the door
And I'm floating in a most peculiar way
And the stars look very different today"""

print(a)

# %% [markdown]
# Using 'format' function to insert numbers into a string.

# %%
a = 7
b = 3
print ('{} x {} = {}'.format(a, b, a * b))

# %%
print ('{} : {} = {}'.format(b, a, b / a))

# %% [markdown]
# ## Boolean variable

# %%
c1 = 2>1

print (t)

c2 = 1==5

print (c2)

# %%
print (c1 and c2)
print (c1 or c2)

# %% [markdown]
# Each varible has a type. We can print it as follows (note the differences)

# %%
a = 7
b = 3
c = a/b

t = a > b

print ('type(a) is: ', type(a))
print ('type(b) is: ', type(b))
print ('type(c) is: ', type(c))

print ('type(t) is: ', type(t))

# %%
print ('{} : {} = {:.2f}'.format(b, a, b/a))

# %% [markdown]
# Getting 'input' from  user

# %%
name = input('What is your name? ')

print ('Hello', name)

print ('Hello', 'name')

# %% [markdown]
# ### Iporting math library

# %%
import math

print (math.pi)

# %%
import datetime

date_time_str = '18/09/19'

date_time_obj = datetime.datetime.strptime(date_time_str, '%d/%m/%y')

print (date_time_obj)

print (date_time_obj.year)

# %%
import datetime
now = datetime.datetime.now()

name = input('What is your name? ')
born_year = input('At what year were you born? ')

age = now.year - born_year

print ('Hi', name, ', you are',age ,'year old.')

# %% [markdown]
# ![www.boi.org.il](https://www.boi.org.il/Style%20Library/Boi/newSite/img/logo.png)
#
# # www.boi.org.il

# %%
from lxml import html
import requests
 
url = "https://www.boi.org.il/currency.xml"

response = requests.get(url)
tree = html.fromstring(response.content)

d2s_rate = float(tree[1][4].text)

print ('1 USD =', d2s_rate, 'NIS' )

# %% [markdown]
# ___
# ___

# %% [markdown]
# # Lesson 2: Arrays, Tuples, Set, Dictionary, Loops, and conditions
#
#
# ### 1.  List is a collection which is ordered and changeable. Allows duplicate members.
# ### 2.  Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
# ### 3.  Set is a collection which is unordered and unindexed. No duplicate members.
# ### 4.  Dictionary is a collection which is unordered, changeable and indexed. No duplicate members.

# %%
a = [1, 2, 8, 4, 1]
b = (1, 2, 8, 4, 1)
c = {1, 2, 8, 4, 1}

print (type(a))
print (type(b))
print (type(c))

# %%
print ('len(a) is', len(a))
print ('len(b) is', len(b))
print ('len(c) is', len(c))
